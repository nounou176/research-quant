# %% [markdown]
# <a href="https://colab.research.google.com/github/nounou176/research-quant/blob/main/QuantTradingAccelerator_Video2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quant Trading Accelerator 🚀

# %% [markdown]
# Learn from 0, extremely fast => JIT Learning => Build, Test, Learn, Iterate 🚀

# %% [markdown]
# ## Part 2: Arrays (The fundamental building block of Quant Trading/AI/ML)

# %%
prices = [10.2, 9.4, 9.9, 10.5]

# %%
prices
# Out:
# [10.2, 9.4, 9.9, 10.5]

# %%
type(prices)
# Out:
# list

# %%
len(prices)
# Out:
# 4

# %% [markdown]
# ### Access elements

# %%
prices[0]
# Out:
# 10.2

# %%
prices[1]
# Out:
# 9.4

# %%
prices[2]
# Out:
# 9.9

# %%
prices[3]
# Out:
# 10.5

# %%
prices[-1]
# Out:
# 10.5

# %%
prices[-2]
# Out:
# 9.9

# %%
prices[-3]
# Out:
# 9.4

# %%
prices[-4]
# Out:
# 10.2

# %%
#prices[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2981730223.py in <cell line: 0>()
# ----> 1 prices[5]
#
# IndexError: list index out of range

# %% [markdown]
# ### Update Elements

# %%
prices[0] = None

# %%
prices
# Out:
# [None, 9.4, 9.9, 10.5]

# %%
prices[-1] = None

# %%
prices
# Out:
# [None, 9.4, 9.9, None]

# %% [markdown]
# ### Remove elements

# %%
prices.pop()

# %%
prices
# Out:
# [None, 9.4, 9.9]

# %%
prices.pop(0)

# %%
prices
# Out:
# [9.4, 9.9]

# %%
del prices[0]

# %%
prices
# Out:
# [9.9]

# %%
del prices[-1]

# %%
prices
# Out:
# []

# %%
n = 200000000
prices_ts = [1.0 for _ in range(n)]

# %%
# %%time
prices_ts.pop(0)
# Out:
# CPU times: user 225 ms, sys: 1.12 ms, total: 226 ms
# Wall time: 226 ms
# 1.0

# %%
prices_ts = [1.0 for _ in range(n)]

# %%
# %%time
prices_ts.pop()
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 8.34 µs
# 1.0

# %%
### Add elements

# %%
prices = []

# %%
prices.append(10.5)

# %%
prices
# Out:
# [10.5]

# %%
prices.extend([11.4, 9.5, 12.3])

# %%
prices
# Out:
# [10.5, 11.4, 9.5, 12.3]

# %% [markdown]
# ### Inhomogeneous Array

# %%
[1.0, "a", True, 2]
# Out:
# [1.0, 'a', True, 2]

# %%
[1.0, 2, 3.0, 4]
# Out:
# [1.0, 2, 3.0, 4]

# %% [markdown]
# ### Homogenerous Array

# %%
[1.0, 2.0, 3.0, 4.0]
# Out:
# [1.0, 2.0, 3.0, 4.0]

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### Loops

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
prices = [10.2, 9.5, 11.5, 9.4]
for price in prices:
  print(price)
# Out:
# 10.2
# 9.5
# 11.5
# 9.4

# %%
trade_pnls = [1.2, -2.0, -1.0, 4.1]

total_pnl = 0.0

for trade_pnl in trade_pnls:
  total_pnl += trade_pnl

total_pnl
# Out:
# 2.3

# %%
1.2 + -2.0 + -1.0 + 4.1
# Out:
# 2.3

# %% [markdown]
# ### Numpy Arrays

# %%
import numpy as np

n = 100000000
a = np.ones(n)

# %%
a
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
len(a)
# Out:
# 100000000

# %%
# %%time
np.sum(a)
# Out:
# CPU times: user 104 ms, sys: 0 ns, total: 104 ms
# Wall time: 104 ms
# np.float64(100000000.0)

# %%
# %%time
sum = 0.0
for val in a:
  sum += val
sum
# Out:
# CPU times: user 20.8 s, sys: 3.39 ms, total: 20.9 s
# Wall time: 21.5 s
# np.float64(100000000.0)

# %% [markdown]
# ### Logarithms (log)

# %%
np.exp(2)
# Out:
# np.float64(7.38905609893065)

# %%
np.log(np.exp(2))
# Out:
# np.float64(2.0)

# %%
### Invest $1000 at a continuous rate of 5% per year

# %%
1000 * 1.05
# Out:
# 1050.0

# %%
1000 * 1.05 * 1.05
# Out:
# 1102.5

# %%
1000 * 1.05 * 1.05 * 1.05
# Out:
# 1157.625

# %%
1000 * 1.05 * 1.05 * 1.05 * 1.05
# Out:
# 1215.5062500000001

# %%
capital = 1000
for _ in range(20):
  capital *= 1.05
capital
# Out:
# 2653.2977051444223

# %%
1000 * 1.05 ** 20
# Out:
# 2653.2977051444223

# %% [markdown]
# ### How long to double our investment?

# %%
capital = 1000
t = 1

2 * capital == capital * 1.05 ** t
# Out:
# False

# %%
2 == (1.05) ** t
# Out:
# False

# %%
np.log(2) == t * np.log(1.05)
# Out:
# np.False_

# %%
t = np.log(2) / np.log(1.05)

# %%
t
# Out:
# np.float64(14.206699082890461)

# %%
capital * 1.05 ** t
# Out:
# np.float64(2000.0)

# %% [markdown]
# ### Why returns?

# %%
pnl = 100

# %%
pnl / 50
# Out:
# 2.0

# %%
pnl / 99
# Out:
# 1.0101010101010102

# %% [markdown]
# ### Log Returns

# %%
portfolio = [100, 120, 100]

# %%
[120-100, 100-120]
# Out:
# [20, -20]

# %%
[20/100, -20/120]
# Out:
# [0.2, -0.16666666666666666]

# %%
log_returns = [np.log(120/100), np.log(100/120)]

# %%
log_returns
# Out:
# [np.float64(0.1823215567939546), np.float64(-0.1823215567939546)]

# %%
np.sum(log_returns)
# Out:
# np.float64(0.0)

# %%
100 * np.sum(log_returns)
# Out:
# np.float64(0.0)

# %% [markdown]
# ### Exercise 1: Calculate the average log return

# %%
log_returns = [-0.1, 0.22, 0.15, 0.344, -0.2]
avg_log_return = 0.0

# %%
#loop goes here

# %%
avg_log_return == 0.0828
# Out:
# False

# %% [markdown]
# ### Exercise 2: Calculate Total Log Returns

# %%
portfolio = [100, 120, 100, 80, 155]
log_returns = []

# %%
#loop goes here

# %%
100 * np.exp(np.sum(log_returns)) == 155.0
# Out:
# np.False_

# %% [markdown]
# ### Exercise 3: Calculate Cumulative Log Returns

# %%
portfolio = [100, 120, 100, 80, 155]
cum_log_returns = []

# %%
# your loop goes here

# %%
cum_log_returns == [np.log(120/100), np.log(120/100) + np.log(100/120), np.log(120/100) + np.log(100/120) + np.log(80/100), np.log(120/100) + np.log(100/120) + np.log(80/100) + np.log(155/80)]
